# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("tanujdhiman/post-recommendation-system")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/post-recommendation-system

# %%
# Load
df = pd.read_csv("/kaggle/input/post-recommendation-system/post_data.csv")
df
# Out:
#                         user_id    post_id           time_stamp  Valuable
# 0      5eece14ffc13ae660900008b  136781766     01-01-2019 13:30          1
# 1      5eece14efc13ae660900003c   43094523     01-01-2019 13:33          2
# 2      5eece14efc13ae6609000025   42428071     01-01-2019 13:43          2
# 3      5eece14ffc13ae66090001d4   76472880     01-01-2019 13:54          2
# 4      5eece14ffc13ae66090000ac  202721843     01-01-2019 14:00          3
# ...                         ...        ...                  ...        ...
# 71795  5eece14ffc13ae660900018c  615389604  12/31/2019 12:37 AM          1
# 71796  5eece14ffc13ae660900010c  348689108  12/31/2019 12:50 PM          1
# 71797  5eece14ffc13ae6609000190  619052165  12/31/2019 12:51 AM          2
# 71798  5eece14efc13ae6609000067  426384418  12/31/2019 12:51 PM          1
# 71799  5eece14ffc13ae6609000110  165390871  12/31/2019 12:54 AM          3
#
# [71800 rows x 4 columns]

# %%
df.columns = df.columns.str.strip()

# %%
if 'Valuable' in df.columns:
    print("The 'Valuable' column exists in the dataset.")
else:
    print("The 'Valuable' column does not exist in the dataset.")
if 'user_id' in df.columns:
    print("The 'user_id' column exists in the dataset.")
else:
    print("The 'user_id' column does not exist in the dataset.")
if 'post_id' in df.columns:
    print("The 'post_id' column exists in the dataset.")
else:
    print("The 'post_id' column does not exist in the dataset.")
# Out:
# The 'Valuable' column exists in the dataset.
# The 'user_id' column exists in the dataset.
# The 'post_id' column exists in the dataset.

# %%
# Encode IDs
user2idx = {id: i for i, id in enumerate(df['user_id'].unique())}
item2idx = {id: i for i, id in enumerate(df['post_id'].unique())}

df['user'] = df['user_id'].map(user2idx)
df['item'] = df['post_id'].map(item2idx)

# Train/test split
train, test = train_test_split(df[['user', 'item', 'Valuable']], test_size=0.2)

# %%
class MF(nn.Module):
    def __init__(self, num_users, num_items, latent_dim=50):
        super(MF, self).__init__()
        self.user_emb = nn.Embedding(num_users, latent_dim)
        self.item_emb = nn.Embedding(num_items, latent_dim)

    def forward(self, u, i):
        return (self.user_emb(u) * self.item_emb(i)).sum(1)

# %%
model = MF(len(user2idx), len(item2idx))
loss_fn = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)

u = torch.tensor(train['user'].values)
i = torch.tensor(train['item'].values)
r = torch.tensor(train['Valuable'].values, dtype=torch.float)

for epoch in range(100):
    model.train()
    optimizer.zero_grad()
    pred = model(u, i)
    loss = loss_fn(pred, r)
    loss.backward()
    optimizer.step()
    print(f"Epoch {epoch+1}: loss = {loss.item():.4f}")
# Out:
# Epoch 1: loss = 60.2325
# Epoch 2: loss = 57.2574
# Epoch 3: loss = 54.4074
# Epoch 4: loss = 51.6807
# Epoch 5: loss = 49.0750
# Epoch 6: loss = 46.5875
# Epoch 7: loss = 44.2155
# Epoch 8: loss = 41.9556
# Epoch 9: loss = 39.8045
# Epoch 10: loss = 37.7587
# Epoch 11: loss = 35.8143
# Epoch 12: loss = 33.9676
# Epoch 13: loss = 32.2148
# Epoch 14: loss = 30.5519
# Epoch 15: loss = 28.9751
# Epoch 16: loss = 27.4805
# Epoch 17: loss = 26.0642
# Epoch 18: loss = 24.7226
# Epoch 19: loss = 23.4520
# Epoch 20: loss = 22.2488
# Epoch 21: loss = 21.1096
# Epoch 22: loss = 20.0309
# Epoch 23: loss = 19.0098
# Epoch 24: loss = 18.0429
# Epoch 25: loss = 17.1275
# Epoch 26: loss = 16.2606
# Epoch 27: loss = 15.4397
# Epoch 28: loss = 14.6621
# Epoch 29: loss = 13.9255
# Epoch 30: loss = 13.2275
# Epoch 31: loss = 12.5660
# Epoch 32: loss = 11.9390
# Epoch 33: loss = 11.3445
# Epoch 34: loss = 10.7806
# Epoch 35: loss = 10.2458
# Epoch 36: loss = 9.7384
# Epoch 37: loss = 9.2568
# Epoch 38: loss = 8.7996
# Epoch 39: loss = 8.3655
# Epoch 40: loss = 7.9533
# Epoch 41: loss = 7.5617
# Epoch 42: loss = 7.1896
# Epoch 43: loss = 6.8360
# Epoch 44: loss = 6.4999
# Epoch 45: loss = 6.1803
# Epoch 46: loss = 5.8765
# Epoch 47: loss = 5.5875
# Epoch 48: loss = 5.3126
# Epoch 49: loss = 5.0512
# Epoch 50: loss = 4.8024
# Epoch 51: loss = 4.5657
# Epoch 52: loss = 4.3405
# Epoch 53: loss = 4.1261
# Epoch 54: loss = 3.9221
# Epoch 55: loss = 3.7279
# Epoch 56: loss = 3.5430
# Epoch 57: loss = 3.3671
# Epoch 58: loss = 3.1996
# Epoch 59: loss = 3.0402
# Epoch 60: loss = 2.8885
# Epoch 61: loss = 2.7440
# Epoch 62: loss = 2.6066
# Epoch 63: loss = 2.4758
# Epoch 64: loss = 2.3513
# Epoch 65: loss = 2.2328
# Epoch 66: loss = 2.1201
# Epoch 67: loss = 2.0128
# Epoch 68: loss = 1.9108
# Epoch 69: loss = 1.8138
# Epoch 70: loss = 1.7215
# Epoch 71: loss = 1.6337
# Epoch 72: loss = 1.5503
# Epoch 73: loss = 1.4709
# Epoch 74: loss = 1.3955
# Epoch 75: loss = 1.3239
# Epoch 76: loss = 1.2558
# Epoch 77: loss = 1.1911
# Epoch 78: loss = 1.1296
# Epoch 79: loss = 1.0712
# Epoch 80: loss = 1.0158
# Epoch 81: loss = 0.9632
# Epoch 82: loss = 0.9132
# Epoch 83: loss = 0.8658
# Epoch 84: loss = 0.8209
# Epoch 85: loss = 0.7782
# Epoch 86: loss = 0.7377
# Epoch 87: loss = 0.6993
# Epoch 88: loss = 0.6629
# Epoch 89: loss = 0.6284
# Epoch 90: loss = 0.5957
# Epoch 91: loss = 0.5647
# Epoch 92: loss = 0.5354
# Epoch 93: loss = 0.5076
# Epoch 94: loss = 0.4812
# Epoch 95: loss = 0.4563
# Epoch 96: loss = 0.4327
# Epoch 97: loss = 0.4103
# Epoch 98: loss = 0.3891
# Epoch 99: loss = 0.3691
# Epoch 100: loss = 0.3502

# %%
def recommend(user_id, top_k=5):
    model.eval()
    u_idx = torch.tensor([user2idx[user_id]] * len(item2idx))
    i_idx = torch.tensor(list(item2idx.values()))
    scores = model(u_idx, i_idx).detach().numpy()
    top_items = sorted(zip(item2idx.keys(), scores), key=lambda x: -x[1])[:top_k]
    return [item for item, _ in top_items]

# Example
print("Top picks:", recommend(user_id='5eece14efc13ae6609000067'))
# Out:
# Top picks: [np.int64(197978977), np.int64(314026585), np.int64(210340443), np.int64(440926148), np.int64(281588551)]
